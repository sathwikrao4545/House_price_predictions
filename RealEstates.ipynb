# %% [markdown]
# ## Real Estate(House) Price Trend Analyzer

# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284804
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705279
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
housing['CHAS'].mean()
# Out:
# np.float64(0.0691699604743083)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=40, figsize=(30, 20))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
  import seaborn as sns

# %%
corelation = housing.corr()

# %%
plt.figure(figsize=(12, 8))  # Try a bigger size


sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)

plt.show()

# %%
sns.displot(housing['CHAS'], bins=5)

# %%
sns.catplot(x='MEDV', kind = 'box', data=housing)
plt.show()

# %%
# Scatter plot between RM and MEDV
plt.figure(figsize=(10, 6))
sns.scatterplot(data=housing, x='RM', y='MEDV')
plt.title('Scatter Plot of RM vs MEDV', fontsize=20)
plt.xlabel('Average Number of Rooms per Dwelling (RM)', fontsize=14)
plt.ylabel('Median Value of Homes in $1000s (MEDV)', fontsize=14)
plt.show()

# %%
# Box plot for MEDV by CHAS (Charles River)
plt.figure(figsize=(10, 6))
sns.boxplot(x='CHAS', y='MEDV', data=housing)
plt.title('Box Plot of MEDV by CHAS', fontsize=20)
plt.xlabel('Charles River Dummy Variable (0 = No, 1 = Yes)', fontsize=14)
plt.ylabel('Median Value of Homes in $1000s (MEDV)', fontsize=14)
plt.show()

# %% [markdown]
# ## Train - Test data Splitting

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state = 42)
print(f"Rows in train set : {len(train_set)}\nRows in test set: {len(test_set)}\n")
# Out:
# Rows in train set : 404
# Rows in test set: 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing,housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     3.655942   13.450980   10.312255    0.068627    0.541353    6.303353
# std     10.400966   27.503241    6.761154    0.254068    0.111397    0.662996
# min      0.009060    0.000000    0.460000    0.000000    0.385000    4.138000
# 25%      0.057827    0.000000    4.950000    0.000000    0.448000    5.912750
# 50%      0.176150    0.000000    7.760000    0.000000    0.515000    6.176000
# 75%      2.061955    0.000000   18.100000    0.000000    0.612750    6.539500
# max     88.976200   90.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean    66.733333    3.988460    8.813725  391.980392   18.385294  369.670196
# ...

# %%
strat_test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 342 to 218
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     102 non-null    float64
#  1   ZN       102 non-null    float64
#  2   INDUS    102 non-null    float64
#  3   CHAS     102 non-null    int64
#  4   NOX      102 non-null    float64
#  5   RM       102 non-null    float64
#  6   AGE      102 non-null    float64
#  7   DIS      102 non-null    float64
#  8   RAD      102 non-null    int64
#  9   TAX      102 non-null    int64
#  10  PTRATIO  102 non-null    float64
#  11  B        102 non-null    float64
#  12  LSTAT    102 non-null    float64
#  13  MEDV     102 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 12.0 KB

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 404 entries, 254 to 216
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     404 non-null    float64
#  1   ZN       404 non-null    float64
#  2   INDUS    404 non-null    float64
#  3   CHAS     404 non-null    int64
#  4   NOX      404 non-null    float64
#  5   RM       399 non-null    float64
#  6   AGE      404 non-null    float64
#  7   DIS      404 non-null    float64
#  8   RAD      404 non-null    int64
#  9   TAX      404 non-null    int64
#  10  PTRATIO  404 non-null    float64
#  11  B        404 non-null    float64
#  12  LSTAT    404 non-null    float64
#  13  MEDV     404 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 47.3 KB

# %%
strat_test_set.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     3.655942   13.450980   10.312255    0.068627    0.541353    6.303353
# std     10.400966   27.503241    6.761154    0.254068    0.111397    0.662996
# min      0.009060    0.000000    0.460000    0.000000    0.385000    4.138000
# 25%      0.057827    0.000000    4.950000    0.000000    0.448000    5.912750
# 50%      0.176150    0.000000    7.760000    0.000000    0.515000    6.176000
# 75%      2.061955    0.000000   18.100000    0.000000    0.612750    6.539500
# max     88.976200   90.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean    66.733333    3.988460    8.813725  391.980392   18.385294  369.670196
# ...

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ## Looking for Correlation

# %%
corr_matrix = housing.corr() 
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680383
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["MEDV", "RM", "ZN", "LSTAT"]
scatter_matrix(housing[attributes], figsize= (12, 8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=0.8)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=0.8)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
housing.plot(kind="scatter", x="RM", y="MEDV", alpha=0.8)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## trying out Attribute Combination

# %%
housing["TAXRM"] = housing['TAX']/housing['RM']

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  399.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.280063
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.716407
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878500
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
corr_matrix = housing.corr() 
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680383
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.529505
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
housing = strat_train_set.drop("MEDV", axis = 1)
housing_labels = strat_train_set["MEDV"].copy()

# %% [markdown]
# ## Missing Attribute

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X = imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(X, columns = housing.columns)

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279183
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.711993
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.879750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ## Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy = "median")),
    ('std_scaler', StandardScaler()),
])

# %%
housing_num_tr = my_pipeline.fit_transform(housing)

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(housing_num_tr, housing_labels)
# Out:
# LinearRegression()

# %%
some_data = housing.iloc[:5]

# %%
some_labels = housing_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([23.99137283, 27.24730275, 20.58322546, 25.04604873, 23.77808969])

# %%
prepared_data[4]
# Out:
# array([-0.40786253, -0.4898311 , -0.57719868, -0.27288841, -0.5573845 ,
#         0.04614867, -1.42222622,  0.79643404, -0.5429938 , -0.74402708,
#         0.52982668,  0.45343469, -0.91902752])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ## Evaluating the model for linear Regression

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
housing_prediction = model.predict(housing_num_tr)

mse = mean_squared_error(housing_labels, housing_prediction)

rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(4.834409537339922)

# %% [markdown]
# ## cross validation for Linear Regression

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring = "neg_mean_squared_error", cv = 10)
rmse_score = np.sqrt(-scores)

# %%
rmse_score
# Out:
# array([4.21879783, 4.26452195, 5.0971233 , 3.83013235, 5.37608825,
#        4.39916785, 7.46889434, 5.48364518, 4.14950523, 6.07213744])

# %%
def print_scores(scores):
    print("scores:", scores)
    print("Mean:", scores.mean())
    print("Satndard Deviation:", scores.std())

# %%
print_scores(rmse_score)
# Out:
# scores: [4.21879783 4.26452195 5.0971233  3.83013235 5.37608825 4.39916785
#  7.46889434 5.48364518 4.14950523 6.07213744]
# Mean: 5.036001372085027
# Satndard Deviation: 1.0592865842631987

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(housing_num_tr, housing_labels)
# Out:
# DecisionTreeRegressor()

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([21.9, 24.5, 16.7, 23.1, 23. ])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ## Evaluating the model for Decision Tree

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
housing_prediction = model.predict(housing_num_tr)

mse = mean_squared_error(housing_labels, housing_prediction)

rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(0.0)

# %% [markdown]
# ## cross validation for Decision Tree

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring = "neg_mean_squared_error", cv = 10)
rmse_score = np.sqrt(-scores)

# %%
rmse_score
# Out:
# array([4.2091364 , 5.67794192, 5.10941264, 3.62965429, 4.22181833,
#        3.5471115 , 4.41486127, 3.95676636, 3.30620629, 3.72102137])

# %%
def print_scores(scores):
    print("scores:", scores)
    print("Mean:", scores.mean())
    print("Satndard Deviation:", scores.std())
print_scores(rmse_score)
# Out:
# scores: [4.2091364  5.67794192 5.10941264 3.62965429 4.22181833 3.5471115
#  4.41486127 3.95676636 3.30620629 3.72102137]
# Mean: 4.179393035226817
# Satndard Deviation: 0.6994876721137006

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(housing_num_tr, housing_labels)
# Out:
# RandomForestRegressor()

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.138, 25.502, 16.51 , 23.301, 23.424])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.24072634, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# ## Evaluating the model for Random Forest

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
housing_prediction = model.predict(housing_num_tr)

mse = mean_squared_error(housing_labels, housing_prediction)

rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(1.2784682095661528)

# %% [markdown]
# ## cross validation for Random Forest

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring = "neg_mean_squared_error", cv = 10)
rmse_score = np.sqrt(-scores)

# %%
rmse_score
# Out:
# array([2.99462062, 2.86018984, 4.39344793, 2.61853848, 3.22919624,
#        2.66706758, 4.49142615, 3.29459827, 3.06526479, 3.13225598])

# %%
def print_scores(scores):
    print("scores:", scores)
    print("Mean:", scores.mean())
    print("Satndard Deviation:", scores.std())
print_scores(rmse_score)
# Out:
# scores: [2.99462062 2.86018984 4.39344793 2.61853848 3.22919624 2.66706758
#  4.49142615 3.29459827 3.06526479 3.13225598]
# Mean: 3.2746605863317035
# Satndard Deviation: 0.6203763065790988

# %% [markdown]
# ## Among 3 models Random forest gives less error for predicting prices

# %% [markdown]
# ## saving the model

# %%
from joblib import dump, load
dump(model, 'RealEstates.joblib')
# Out:
# ['RealEstates.joblib']

# %% [markdown]
# ## Testing the model on test data

# %%
X_test = strat_test_set.drop("MEDV", axis=1)
Y_test = strat_test_set["MEDV"].copy()
X_test_prepared = my_pipeline.transform(X_test)
final_predictions = model.predict(X_test_prepared)
final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# np.float64(3.0354430209334073)

# %% [markdown]
# ## Using the model for predictions

# %%
from joblib import dump, load
model = load('RealEstates.joblib')
features = np.array([[-0.40786253, -0.4898311 , -0.57719868, -0.27288841, -0.5573845 ,
        0.04614867, -1.42222622,  0.79643404, -0.5429938 , -0.74402708,
        0.52982668,  0.45343469, -0.91902752]])
model.predict(features)
# Out:
# array([23.424])
